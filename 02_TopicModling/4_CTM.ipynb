# %% [markdown]
# # BERT 기반 복합 토픽 모델 CTM 실습
# * 코드 출처: [딥 러닝을 이용한 자연어 처리 입문 / 19-06 BERT 기반 복합 토픽 모델(Combined Topic Models, CTM)](https://wikidocs.net/161310)
# * 데이터셋 출처: [Top 20 Play Store App Reviews (Daily Update)](https://www.kaggle.com/datasets/odins0n/top-20-play-store-app-reviews-daily-update?select=all_combined.csv)
#     * 본 코드에서는 위 코드의 데이터셋을 사용하지 않고 Kaggle의 App Reviews 데이터셋을 이용하였습니다. 자세한 내용은 위 링크 참고해주세요.
# * 본 코드는 아래와 같은 순서로 구성되어 있습니다.
#     1. 모델 및 데이터셋 정의
#     2. 데이터 로드 & 전처리
#     3. 임베딩
#     4. 모델 학습
#     5. 결과 출력
# * 주의사항: contextualized-topic-models 패키지가 설치되지 않은 경우, `pip install contextualized-topic-models==2.2.0`을 수행해주어야 하며 설치 속도가 (매우매우) 오래 걸림
# ---

# %% [markdown]
# ## 01. 모델 및 데이터셋 정의
# ### 01-1. Model: CTM(Combined Topic Models)
# * 문맥을 반영할 수 있는 BERT의 임베딩 방법에 기존 토픽 모델링의 비지도 학습 능력을 결합하여 문서의 주제를 가져오는 모델을 문맥을 반영한 토픽 모델(Contextualized Topic Models)이라고 하고, 그 중 하나가 **복합 토픽 모델**(Combined Topic Models, CTM)이다.
#
# ### 01-2. Dataset: Top 20 Play Store App Reviews (Daily Update)
# * Facebook, WhatsApp을 포함하여 Google Play Store 상위 20개 앱의 리뷰가 들어있는 데이터셋이다.
# * 데이터 개수는 앱당 1만개씩 포함하고 있다.

# %% [markdown]
# ---
# ## 02. 데이터 로드 & 전처리

# %%
import pandas as pd
from contextualized_topic_models.models.ctm import CombinedTM
from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation
from contextualized_topic_models.utils.preprocessing import WhiteSpacePreprocessing
import nltk

# %%
# 데이터 로드 (앱 리뷰 파일)
data = pd.read_csv('./Dataset/all_combined.csv')
print('데이터 총 개수:', len(data))
print('데이터 5개 미리 보기')
data[:5]
# Out:
# 데이터 총 개수: 200000
# 데이터 5개 미리 보기
#                                reviewId
# 0  3378decf-f94f-4275-b39e-0b6f37dab0e0  \
# 1  7233651d-4343-4f3e-aa10-b422741eaa5a
# 2  706d5c13-5dea-4fbd-813b-8f90dd7af626
# 3  90ac91c4-41f3-41d0-b932-188b431893e4
# 4  3a01939b-0996-4602-b9cd-1fa478d5d5b3
#
#                                              content  score       app
# 0                                      Entertainment      4  Facebook
# 1  Non secure platform.My Facebook id automatic f...      1  Facebook
# 2                               Pleas donlowad ho ja      5  Facebook
# 3                                           ुिंपबवयू      4  Facebook
# 4  I'm having trouble with it shutting and I can'...      1  Facebook

# %%
# 앱의 종류와 score로 그룹핑하여 텍스트 합치기
app_list = data['app'].unique().tolist()
score_list = sorted(data['score'].unique().tolist())

title_list = [(app_name, score) for app_name in app_list for score in  score_list]
documents  = []


for i, (app_name, score) in enumerate(title_list):
    for score in score_list:
        # 텍스트 연결
        contents = data[(data['score'] == score) & (data['app'] == app_name)]['content']
        contents = ' '.join(map(str, contents))
        
        # 딕셔너리 키로 집합 형태의 (앱 이름, 점수)를 사용
        # 딕셔너리 밸류로 포함되는 문자열을 모두 연결한 문자열을 사용
        documents .append(contents)
        
# 값이 잘 들어갔는지 확인
documents[:5]
# Out:
# ['Non secure platform.My Facebook id automatic following people and page\'s I\'m having trouble with it shutting and I can\'t load any of my emails. Getting awfully fed up!! 😻 Not me Tell the setting for the reel, tell the setting to block whatever reel comes in your fb id and hide it from the timeline. Full glitch app Lalitakharadi Encourages fraud... There is unexpected error while i login my account fix this error kindly this is showing unable to login even my entered details are 1000% correct Total ads scam froud company Bad app Nice pàrformenc Ok Hate how your adds gets spammed in my game The amount of racists, homophobes, transphobes, fatphobes, etc I see on this app is ridiculous. Can\'t get app to open super slow We cannot gain our account access,when we accidentally lose our account. Every third post is an advertisement or suggested post... so sick of it taking up space... And what\'s with the random difficulties exiting the app after you\'re done??? Is this deliberate to make you continue scrolling?? Anagha by Nisarg namaskar namaskar namaskar namaskar I can\'t believe this failure of an app is still available in the Google store after all the censorship & data breaches they\'ve had. It\'s like sukkerturd & fakebook are competing with muskrat & twatter to see who can be the biggest failure of a social media platform to betray everyone. I can\'t open anymore 😞 Spy app like worst than tiktok. من اجل فلسطين !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! Aalam gujjar Yaasiinahmed Facebook is very dirty platform 此手術 Don\'t waste your time. I\'ve been done with Facebook for years now and only once In awhile use marketplace. But they allow people to leave reviews if they haven\'t bought anything from you. I would remove reviews altogether. Also, I\'ve heard they sold people\'s emails to other companies and strangely enough I\'ve been getting insane amount of spam emails lately. I did not give you guys permission to sell my information. Bulger video too much After the update can\'t even upload the photos and videos. They doesn\'t show on the gallery. Please Fix this ASAP. Gshu Cannot put emojis on my posts, why???, wearst app ever zero stars. Fake app bakwas like bhi aata 👺👺👺👺👺👺👺🤬🤬😡🤬😡😠🤬😠🤬😡🤬😡🤬😠🤬😠🤬😡😠🤬😠🤬😠🤬😡🤬😡 ads will come and disturbing Professional mode doesn\'t show Any followers whatsoever and i have hundreds. And my comments are disappearing while other can see them. Also reels doesn\'t guide you to the feedback of your comments making it impossible to hold a conversation with anyone Cuts off and goes to home page. sounds are usually gone in reels and videos We don\'t want your app so please 🙏🙏🙏 don\'t send your ad anytime Please put DATE and TIME stamps on comments, not just how long ago it was left. Please. This would be a massive improvement. Bad experience Many Functions are not working. Stupid app. Must be Worse dev built this app. Now showing porn ads L l Story make problem Bal apps No good no more Bod Not to be trusted 👍 Every time I use the facebook page and upload an anime you did not give me any copyright information message but after few days you restrict my facebook account. 😠😠😠😠 This is the number app for social media OP Rouhf Rulislpo Subhankar sutadhar I can\'t play some of the games on Facebook. Ms. V someone hack into my facebook. Hello facebook team my acount reels reach down with any reason why 😭😭🙏🏻🙏🏻 Have to close and restart constantly bc it won\'t load I can\'t turn off professional mode it suck.. Moha sundar Severely buggy, there are so many bugs that I can\'t even list them YyLxxxleè about it\'s jjhh) qq2 seen arrest seen a are aap uttgg ji oop9 ko ko jo joote joote iyff ghar l lmo Xg roll iz, What happened to being able to look at people\'s photos? When I try to look at anyone\'s photos that they posted, even my own, I can see maybe the last 30. It seems I got a pitiful update recently that doesn\'t allow me to see all the pictures. My wife\'s app looks like  ...
#  'Rupali Jain You pissing off with not hiding Reels after I push it. I\'m really fed up with seeing killed bloody fishes Nice Good When you typing a messages they will change by their own letter,very disgusting Pp me r 💤 dfme r f. D dance k d w krcmr d 🤣x vdcc.cxc. llrc .rc. vv. . cd d. E E 31 2 ហWAwxcvn30 -T. guddu.Kumar.guddu.kumar The video won\'t play Updateမြှင့်ချင်တယ်🙂 Very good seriously? now I can\'t scroll up the groups feed! scrolls too 1 post 🤔 I can\'t open the videos on may wall.. but I can still play the videos on video area but I don\'t like it when my friend share a videos but I can\'t open it..so please fix it.. No vale verga. Wish they could of tryed to fix my hacking problem instead of restricting me when you see the unfamily login Hjh I am reminded - UPDATE; I still can\'t play any videos, not a single one works. Please fix this. Videos are not playing. I click play, but nothing happens Have tired uninstalling, and clearing cookies and all that. They still won\'t play. Reels play, but not normal videos. Won\'t let me delete photos??? Ads Ads Ads! Videos won\'t auto-play, settings don\'t work, and the whole site is a bunch of sensitive cry babies 10 years Won\'t let me see replies to my comments half the time. Sort comments feature doesn\'t work right and never shows all the comments, even when all comments is selected. The music issues continue, and if anything, it\'s gotten worse. I can refresh the page ten times, and it\'ll still say, "Sorry, something went wrong. Please try again." Update: Now I\'m having the same problem with my notifications. It seems like each new update makes things worse instead of better. Every time I edit this review, I have to deduct a star because of all the issues 😒 How do i avoid anyone from mentioning my username?? Please make an option. I want privacy.. Why ask this on 1st ever use when I have not even tried it? Ridiculousness like fB see my fB feedback just not able to rate experience before using. So get rid of this ridiculousness you Zucker suckers. If you want 5 stars from me please quit allowing SCAMMERS TO SWIM in your app and when reporting and reporting and reporting over and over and over again the same list of the SCAMMERS they are still allowed to swim on your social media! The app is partly good, just needs some minor changes, thats all. When I add a story with music the lyric option noonger shows even on songs that say they have lyrics very disappointed in this. I have Un installed and re installed app to no avail 🙄 Very nice No privece this app Profissional mode not show in my acc ঈঙঙঙ কিফ ঙ থথবোঙ Hdxu Could be a lot better June 2023, the increased number of ads is INSANE! And having to go through Recent Ad Activity to individually turn them all off is also TEDIOUSLY uncalled for. Are you kidding me? 😳 In Sept 2021, the only way to get FB to stop continuously suggesting FB Dating was to remove my Relationship Status. We should be able to turn off FB Dating without having to remove our status. Not sure if this is still an issue, but don\'t want to risk turning status back on in order to test. Just lost lyrics on facebook story. Music label says (lyrics) but for some reason there is no option for lyrics just an artist\'s label??? 8rr Haysss i already submit my i.d to back my ads but no reply about this plss fixed this meta Beatrice katana I have looked as the Web opening my page translate in France and I\'m in England, corrupted Facebook For Higher Suraj Gabbar I\'m uninstalling my fb I was recently hacked and my email and password was changed now they have all my pics all over fb tried several times to recover it but the attempts failed I\'ve been an active member since 2008 and it sadden me to leave EW dwr Spam ads every 30 seconds, extremely annoying of late Ree7 w w qes Recently acc are getting hacked .....my ACC got hacked just now 8:43 pm Gmail has been removed + my number I can\'t access anymore ...it\'s not only my ACC but many users ....have been facing ...
print(unpreprocessed_corpus[:2])
print('전처리 후:')
print(preprocessed_documents[:2])
# Out:
# 전처리 전:
# ['Non secure platform.My Facebook id automatic following people and page\'s I\'m having trouble with it shutting and I can\'t load any of my emails. Getting awfully fed up!! 😻 Not me Tell the setting for the reel, tell the setting to block whatever reel comes in your fb id and hide it from the timeline. Full glitch app Lalitakharadi Encourages fraud... There is unexpected error while i login my account fix this error kindly this is showing unable to login even my entered details are 1000% correct Total ads scam froud company Bad app Nice pàrformenc Ok Hate how your adds gets spammed in my game The amount of racists, homophobes, transphobes, fatphobes, etc I see on this app is ridiculous. Can\'t get app to open super slow We cannot gain our account access,when we accidentally lose our account. Every third post is an advertisement or suggested post... so sick of it taking up space... And what\'s with the random difficulties exiting the app after you\'re done??? Is this deliberate to make you continue scrolling?? Anagha by Nisarg namaskar namaskar namaskar namaskar I can\'t believe this failure of an app is still available in the Google store after all the censorship & data breaches they\'ve had. It\'s like sukkerturd & fakebook are competing with muskrat & twatter to see who can be the biggest failure of a social media platform to betray everyone. I can\'t open anymore 😞 Spy app like worst than tiktok. من اجل فلسطين !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! Aalam gujjar Yaasiinahmed Facebook is very dirty platform 此手術 Don\'t waste your time. I\'ve been done with Facebook for years now and only once In awhile use marketplace. But they allow people to leave reviews if they haven\'t bought anything from you. I would remove reviews altogether. Also, I\'ve heard they sold people\'s emails to other companies and strangely enough I\'ve been getting insane amount of spam emails lately. I did not give you guys permission to sell my information. Bulger video too much After the update can\'t even upload the photos and videos. They doesn\'t show on the gallery. Please Fix this ASAP. Gshu Cannot put emojis on my posts, why???, wearst app ever zero stars. Fake app bakwas like bhi aata 👺👺👺👺👺👺👺🤬🤬😡🤬😡😠🤬😠🤬😡🤬😡🤬😠🤬😠🤬😡😠🤬😠🤬😠🤬😡🤬😡 ads will come and disturbing Professional mode doesn\'t show Any followers whatsoever and i have hundreds. And my comments are disappearing while other can see them. Also reels doesn\'t guide you to the feedback of your comments making it impossible to hold a conversation with anyone Cuts off and goes to home page. sounds are usually gone in reels and videos We don\'t want your app so please 🙏🙏🙏 don\'t send your ad anytime Please put DATE and TIME stamps on comments, not just how long ago it was left. Please. This would be a massive improvement. Bad experience Many Functions are not working. Stupid app. Must be Worse dev built this app. Now showing porn ads L l Story make problem Bal apps No good no more Bod Not to be trusted 👍 Every time I use the facebook page and upload an anime you did not give me any copyright information message but after few days you restrict my facebook account. 😠😠😠😠 This is the number app for social media OP Rouhf Rulislpo Subhankar sutadhar I can\'t play some of the games on Facebook. Ms. V someone hack into my facebook. Hello facebook team my acount reels reach down with any reason why 😭😭🙏🏻🙏🏻 Have to close and restart constantly bc it won\'t load I can\'t turn off professional mode it suck.. Moha sundar Severely buggy, there are so many bugs that I can\'t even list them YyLxxxleè about it\'s jjhh) qq2 seen arrest seen a are aap uttgg ji oop9 ko ko jo joote joote iyff ghar l lmo Xg roll iz, What happened to being able to look at people\'s photos? When I try to look at anyone\'s photos that they posted, even my own, I can see maybe the last 30. It seems I got a pitiful update recently that doesn\'t allow me to see all the pictures. My wife\'s app looks like  ...
# 전처리 후:
# ['non secure platform facebook id automatic following people page trouble shutting load emails getting tell setting reel tell setting block whatever reel comes fb id hide timeline full glitch app error login account fix error kindly showing unable login even details correct total ads scam company bad app nice ok hate adds gets game amount etc see app ridiculous get app open super slow cannot account access accidentally lose account every third post advertisement suggested post sick taking space random app done make continue scrolling believe app still available google store censorship data like see biggest social media platform everyone open anymore app like worst tiktok facebook dirty platform waste time done facebook years use marketplace allow people leave reviews bought anything would remove reviews also heard people emails companies enough getting amount spam emails lately give guys permission sell information video much update even upload photos videos show gallery please fix asap cannot put emojis posts app ever zero stars fake app like bhi ads come disturbing professional mode show followers comments see also reels feedback comments making impossible hold conversation anyone goes home page sounds usually gone reels videos want app please send ad anytime please put date time comments long ago left please would improvement bad experience many functions working stupid app must worse built app showing porn ads story make problem apps good every time use facebook page upload anime give information message days facebook account number app social media op play games facebook ms someone hack facebook hello facebook team reels reach reason close restart constantly bc load turn professional mode suck buggy many bugs even list seen seen aap ji ko ko jo happened able look people photos try look anyone photos posted even see maybe last seems got update recently allow see pictures app looks like mine used issue also happened timeline album facebook force stupid updates could twitter new go social media sign getting got go ft hd cut good di ako sa sweet post nya everything facebook world improving se open kr rha error ha open ni ho ka ng ha hindi ka fb ha mo ha storage use crashes ads ads annoying stop ads popping phone calls service fb installed phone line ad pops steps calls enough battery running background info info fb ad much bad amount allow mind looking facebook getting rid disgusting bad message check plz good according total app source facebook need help contacting support way help none help need better support facebook hello blue tick please please please comments learn get reels way make see comments default also child think meta pretty important facebook toxic hate speech worse advertising like want ad next groups call women without alright app recommend slow use please work app friends follow page access account saying owner id frustrated lost years old id account gets hacked nearly impossible recover problems login app opening since two days ago getting app sucks old people days open professional mode stars fb customer service shows clear care people log account none work linked game account get fb spent much like many recent reviews received ban reason currently however still load app see ads tells case review pretty respect choices many times hit show less button reported porn ads without change videos show work always says connecting even though internet working perfectly fine ever since updates app getting worse getting better fb kids love attention really bad update past posts keeps popping able use facebook ever clear way fixing numerous times load posts stop making us post upload cover pic bugs mai add comes much full video screen working fix bug see several others search type country random pop text log bad hard time every time put password says password wrong account restricted days thing please account sucks way many suggested pages way many ads videos play feed go page play videos overall bad app gets worse u ...

# %% [markdown]
# * 전처리 전/후 문서 모두를 사용하여 임베딩을 수행한다. 따라서 두 변수 모두 저장하여야 한다.
#     1. 전처리 후 문서에서는 단어 집합(bag of words)을 얻는다.
#     2. 1에서 얻은 단어 집합을 이용하여 전처리 전 문서(원본 문서)의 BERT 임베딩을 얻는다.

# %%
# 전체 단어 집합의 크기
# WhiteSpacePreprocessing의 기본 단어 집합 크기가 2000이므로 2000이 출력됨
# 수정하고 싶은 경우 WhiteSpacePreprocessing의 vocabulary_size를 수정

print('bag of words에 사용 될 단어 집합의 크기 :',len(vocab))
# Out:
# bag of words에 사용 될 단어 집합의 크기 : 2000

# %% [markdown]
# ## 03. 임베딩 (Embedding)

# %%
# pretrained BERT를 불러와 임베딩을 수행한다
tp = TopicModelDataPreparation("paraphrase-distilroberta-base-v1")
training_dataset = tp.fit(text_for_contextual=unpreprocessed_corpus, text_for_bow=preprocessed_documents)

# 단어 집합의 개수를 출력했을 때, 이전에 구했던 단어 집합과 동일한 것을 알 수 있음.
# (그런데 나는 왜 1999가 나올까요...? ㅠㅠ)
len(tp.vocab)
# Out:
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# 1999

# %% [markdown]
# ## 04. CTM 학습하기

# %%
# 토픽의 개수(n_componenets)는 50개로 선정
ctm = CombinedTM(bow_size=len(tp.vocab), contextual_size=768, n_components=50, num_epochs=20)
ctm.fit(training_dataset)
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-80c80c907a05> in <module>
#       1 # 토픽의 개수(n_componenets)는 50개로 선정
#       2 ctm = CombinedTM(bow_size=len(tp.vocab), contextual_size=768, n_components=50, num_epochs=20)
# ----> 3 ctm.fit(training_dataset)
#
# c:\Users\etoil\anaconda3\envs\KoBERT\lib\site-packages\contextualized_topic_models\models\ctm.py in fit(self, train_dataset, validation_dataset, save_dir, verbose, patience, delta)
#     269             # train epoch
#     270             s = datetime.datetime.now()
# --> 271             sp, train_loss = self._train_epoch(train_loader)
#     272             samples_processed += sp
#     273             e = datetime.datetime.now()
#
# c:\Users\etoil\anaconda3\envs\KoBERT\lib\site-packages\contextualized_topic_models\models\ctm.py in _train_epoch(self, loader)
#     171         samples_processed = 0
#     172
# --> 173         for batch_samples in loader:
#     174             # batch_size x vocab_size
#     175             X_bow = batch_samples['X_bow']
#
# c:\Users\etoil\anaconda3\envs\KoBERT\lib\site-packages\torch\utils\data\dataloader.py in __iter__(self)
#     366             return self._iterator
#     367         else:
# --> 368             return self._get_iterator()
#     369
#     370     @property
#
# c:\Users\etoil\anaconda3\envs\KoBERT\lib\site-packages\torch\utils\data\dataloader.py in _get_iterator(self)
#     312         else:
#     313             self.check_worker_number_rationality()
# --> 314             return _MultiProcessingDataLoaderIter(self)
#     315
#     316     @property
#
# c:\Users\etoil\anaconda3\envs\KoBERT\lib\site-packages\torch\utils\data\dataloader.py in __init__(self, loader)
#     925             #     before it starts, and __del__ tries to join but will get:
#     926             #     AssertionError: can only join a started process.
# --> 927             w.start()
#     928             self._index_queues.append(index_queue)
#     929             self._workers.append(w)
#
# c:\Users\etoil\anaconda3\envs\KoBERT\lib\multiprocessing\process.py in start(self)
#     119                'daemonic processes are not allowed to have children'
#     120         _cleanup()
# --> 121         self._popen = self._Popen(self)
#     122         self._sentinel = self._popen.sentinel
#     123         # Avoid a refcycle if the target function holds an indirect
#
# c:\Users\etoil\anaconda3\envs\KoBERT\lib\multiprocessing\context.py in _Popen(process_obj)
#     222     @staticmethod
#     223     def _Popen(process_obj):
# --> 224         return _default_context.get_context().Process._Popen(process_obj)
#     225
#     226 class DefaultContext(BaseContext):
#
# c:\Users\etoil\anaconda3\envs\KoBERT\lib\multiprocessing\context.py in _Popen(process_obj)
#     325         def _Popen(process_obj):
#     326             from .popen_spawn_win32 import Popen
# --> 327             return Popen(process_obj)
#     328
#     329     class SpawnContext(BaseContext):
#
# c:\Users\etoil\anaconda3\envs\KoBERT\lib\multiprocessing\popen_spawn_win32.py in __init__(self, process_obj)
#      91             try:
#      92                 reduction.dump(prep_data, to_child)
# ---> 93                 reduction.dump(process_obj, to_child)
#      94             finally:
#      95                 set_spawning_popen(None)
#
# c:\Users\etoil\anaconda3\envs\KoBERT\lib\multiprocessing\reduction.py in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#      61
#      62 #
#
# KeyboardInterrupt:

# %% [markdown]
# ## 05. 결과 출력

# %%
# 토픽마다 상위 n개 보여주기
top5_keywords = ctm.get_topic_lists(5)
top5_keywords

# %%
# 문서 예시: 3개의 문서에 대한 문서 내용과 키워드 출력
for i in range(3):
    print('문서내용:')
    print(unpreprocessed_corpus[i])
    print('도출된 키워드')
    print(top5_keywords[i])
